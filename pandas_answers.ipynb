# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

fig, ax = plt.subplots()
x = np.linspace(norm.ppf(0.01),
                norm.ppf(0.99), 100)

ax.plot(x, norm.pdf(x),
       'r-', lw=5, alpha=0.6)

ax.plot(x, np.full(len(x), 0.2),
       'b-', lw=1)

fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas
import numpy as np

# %%
import pandas

fileIn="./data/TCL_wt1.tsv"
df = pandas.read_csv(fileIn, sep="\t", na_values='#VALEUR!', 
                     dtype = {'Accession'                       : str,
                              'Description'                     : str, 
                              'Gene Symbol'                     : str, 
                              'Corrected Abundance ratio (1.53)': np.float,
                              'Log2 Corrected Abundance Ratio' : np.float, 
                              '-LOG10 Adj.P-val': np.float,
                              'Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)': np.float,
                             })
print(len(df))
# Out:
# 2024

# %%
from math import sqrt, pow


_ = df["Log2 Corrected Abundance Ratio"].dropna(how="any")
Log2_abundance_ratio = _.tolist()


fig, ax = plt.subplots()

hist = ax.hist(Log2_abundance_ratio, bins=100 )
mu = np.mean(Log2_abundance_ratio)
S_2 = (len(Log2_abundance_ratio) / (len(Log2_abundance_ratio) - 1) ) * pow(np.std(_), 2)
sigma=sqrt(S_2)
print(mu, S_2)

x = np.linspace(min(Log2_abundance_ratio), max(Log2_abundance_ratio), 100)
dx = hist[1][1] - hist[1][0]
scale = len(Log2_abundance_ratio)*dx
ax.plot(x, norm.pdf(x, mu, sigma)*scale)

ax.set_xlabel("Log2 Corrected Abundance Ratio")
ax.set_ylabel('protein counts')


fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# -0.6467130248461945 0.2183080071303949

# %%
df2 = df[ ['Accession', 'Log2 Corrected Abundance Ratio', '-LOG10 Adj.P-val'] ].dropna(how="any")
df2
# Out:
#      Accession  Log2 Corrected Abundance Ratio  -LOG10 Adj.P-val
# 0       P75936                       -3.721335          4.260067
# 1       P76231                       -3.429569          3.454627
# 2       P0A8S9                       -3.284695          4.571899
# 4       P05706                       -3.204277          1.699768
# 5       P29744                       -3.009460          1.434787
# ...        ...                             ...               ...
# 2011    P77330                        0.619129          0.507623
# 2016    P02930                        0.634396          1.873757
# 2020    P0A917                        0.659686          2.652391
# 2021    P02931                        0.811390          4.164956
# 2022    P0AB40                        0.846424          1.444561
#
# [1750 rows x 3 columns]

# %%
x_label, ylabel = df2.columns.values[1:]
# if native python parsing
x_values = df2['Log2 Corrected Abundance Ratio'].to_list()
y_values = df2['-LOG10 Adj.P-val'].to_list()


mu = np.mean(x_values)
sigma = np.std(x_values)

x_thresh =  mu + sigma
y_thresh  =  3 # 0.001


fig, ax = plt.subplots()
ax.scatter(x_values, y_values, marker='o')

ax.set_xlabel(x_label)
ax.set_ylabel(ylabel)
ax.plot(ax.get_xlim(), (y_thresh, y_thresh), color='black',linestyle="dashed", linewidth=0.7)
ax.plot((x_thresh, x_thresh), ax.get_ylim(), color='black',linestyle="dashed", linewidth=0.7)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df3=df2.loc[(df2['-LOG10 Adj.P-val'] > y_thresh )  & (df2['Log2 Corrected Abundance Ratio'] > x_thresh ) ]
df3
# Out:
#      Accession  Log2 Corrected Abundance Ratio  -LOG10 Adj.P-val
# 1862    P0A8V6                       -0.149909          3.454627
# 1898    P0A9Q1                       -0.102570          3.866640
# 1929    P02358                       -0.013262          4.202292
# 1968    P0ACF8                        0.115042          4.571899
# 1977    P62399                        0.181404          5.258216
# 1979    P0A905                        0.231256          4.291580
# 1982    P76506                        0.279442          4.851298
# 1984    P13036                        0.299501          4.571899
# 1989    P10384                        0.360263          3.732993
# 1992    P06971                        0.371240          5.156463
# 1996    P0A910                        0.372697          5.105776
# 2003    P06996                        0.461659          6.091511
# 2009    P76344                        0.588102          4.907876
# 2021    P02931                        0.811390          4.164956

# %%
from xml.etree.ElementTree import parse, dump

def getAccessionGOTerms(xmlFile, accession):
    tree = parse(xmlFile)
    root = tree.getroot()
    ns = '{http://uniprot.org/uniprot}'
    
    match_go_terms = []
    proteins = root.findall(ns + 'entry')
    for entry in proteins:
        accessions = entry.findall(ns+"accession")
        current_accessions = [ acc.text for acc in accessions ]
        if not accession in current_accessions:
            continue
        goTerms = entry.findall('{http://uniprot.org/uniprot}dbReference[@type="GO"]')
        #goTerms = xmlEntry.findall(ns +'dbReference[@type="GO"]')
        for goT in goTerms:
            gID   = goT.attrib['id']
            gName = goT.find(ns +'property[@type="term"]').attrib['value']
            match_go_terms.append((gID, gName))
        break
    return match_go_terms
getAccessionGOTerms("./data/uniprot-proteome_UP000000625.xml", "P0A8V6")
# Out:
# [('GO:0005829', 'C:cytosol'),
#  ('GO:0003677', 'F:DNA binding'),
#  ('GO:0003700', 'F:DNA-binding transcription factor activity'),
#  ('GO:0000062', 'F:fatty-acyl-CoA binding'),
#  ('GO:0019395', 'P:fatty acid oxidation'),
#  ('GO:0045892', 'P:negative regulation of transcription, DNA-templated'),
#  ('GO:0045723', 'P:positive regulation of fatty acid biosynthetic process'),
#  ('GO:0045893', 'P:positive regulation of transcription, DNA-templated'),
#  ('GO:0019217', 'P:regulation of fatty acid metabolic process')]

# %%
abundant_proteins_go_terms = {}

for accession in df3["Accession"].to_list():
    found_go_terms = getAccessionGOTerms("./data/uniprot-proteome_UP000000625.xml", accession)
    for (GO_id, GO_name) in found_go_terms:
        if GO_id not in abundant_proteins_go_terms:
            abundant_proteins_go_terms[GO_id] = {
                "ID"    : GO_id,
                "name"  : GO_name,
                "carried_by" : []
            }
        abundant_proteins_go_terms[GO_id]['carried_by'].append(accession)
    print(accession)

abundant_proteins_go_terms
# Out:
# P0A8V6
# P0A9Q1
# P02358
# P0ACF8
# P62399
# P0A905
# P76506
# P13036
# P10384
# P06971
# P0A910
# P06996
# P76344
# P02931
# {'GO:0005829': {'ID': 'GO:0005829',
#   'name': 'C:cytosol',
#   'carried_by': ['P0A8V6', 'P0A9Q1', 'P02358', 'P0ACF8', 'P62399', 'P76344']},
#  'GO:0003677': {'ID': 'GO:0003677',
#   'name': 'F:DNA binding',
#   'carried_by': ['P0A8V6', 'P0ACF8']},
#  'GO:0003700': {'ID': 'GO:0003700',
#   'name': 'F:DNA-binding transcription factor activity',
#   'carried_by': ['P0A8V6', 'P0A9Q1']},
#  'GO:0000062': {'ID': 'GO:0000062',
#   'name': 'F:fatty-acyl-CoA binding',
#   'carried_by': ['P0A8V6']},
#  'GO:0019395': {'ID': 'GO:0019395',
#   'name': 'P:fatty acid oxidation',
#   'carried_by': ['P0A8V6']},
#  'GO:0045892': {'ID': 'GO:0045892',
#   'name': 'P:negative regulation of transcription, DNA-templated',
#   'carried_by': ['P0A8V6', 'P0A9Q1', 'P0ACF8']},
#  'GO:0045723': {'ID': 'GO:0045723',
#   'name': 'P:positive regulation of fatty acid biosynthetic process',
#   'carried_by': ['P0A8V6']},
#  'GO:0045893': {'ID': 'GO:0045893',
#   'name': 'P:positive regulation of transcription, DNA-templated',
#   'carried_by': ['P0A8V6', 'P0A9Q1']},
#  'GO:0019217': {'ID': 'GO:0019217',
#   'name': 'P:regulation of fatty acid metabolic process',
#   'carried_by': ['P0A8V6']},
#  'GO:0032993': {'ID': 'GO:0032993',
#   'name': 'C:protein-DNA complex',
#   'carried_by': ['P0A9Q1', 'P0ACF8']},
#  'GO:0001216': {'ID': 'GO:0001216',
#   'name': 'F:DNA-binding transcription activator activity',
#   'carried_by': ['P0A9Q1']},
#  'GO:0001217': {'ID': 'GO:0001217',
#   'name': 'F:DNA-binding transcription repressor activity',
#   'carried_by': ['P0A9Q1', 'P0ACF8']},
#  'GO:0042802': {'ID': 'GO:0042802',
#   'name': 'F:identical protein binding',
#   'carried_by': ['P0A9Q1', 'P0ACF8', 'P0A910', 'P02931']},
#  'GO:0000156': {'ID': 'GO:0000156',
#   'name': 'F:phosphorelay response regulator activity',
#   'carried_by': ['P0A9Q1']},
#  'GO:0000976': {'ID': 'GO:0000976',
#   'name': 'F:transcription regulatory region sequence-specific DNA binding',
#   'carried_by': ['P0A9Q1', 'P0ACF8']},
#  'GO:0000160': {'ID': 'GO:0000160',
#   'name': 'P:phosphorelay signal transduction system',
#   'carried_by': ['P0A9Q1']},
#  'GO:0006355': {'ID': 'GO:0006355',
#   'name': 'P:regulation of transcription, DNA-templated',
#   'carried_by': ['P0A9Q1']},
#  'GO:0022627': {'ID': 'GO:0022627',
#   'name': 'C:cytosolic small ribosomal subunit',
#   'carried_by': ['P02358']},
#  'GO:0048027': {'ID': 'GO:0048027',
#   'name': "F:mRNA 5'-UTR binding",
#   'carried_by': ['P02358']},
#  'GO:0070181': {'ID': 'GO:0070181',
#   'name': 'F:small ribosomal subunit rRNA binding',
#   'carried_by': ['P02358']},
#  'GO:0003735': {'ID': 'GO:0003735',
#   'name': 'F:structural constituent of ribosome',
#   'carried_by': ['P02358', 'P62399']},
#  'GO:0006412': {'ID': 'GO:0006412',
#   'name': 'P:translation',
#   'carried_by': ['P02358', 'P62399']},
#  'GO:0016020': {'ID': 'GO:0016020',
#   'name': 'C:membrane',
#   'carried_by': ['P0ACF8', 'P0A910']},
#  'GO:0009295': {'ID': 'GO:0009295',
#   'name': 'C:nucleoid',
#   'carried_by': ['P0ACF8']},
#  'GO:0003680': {'ID': 'GO:0003680',
#   'name': 'F:AT DNA binding',
#   'carried_by': ['P0ACF8']},
#  'GO:0003681': {'ID': 'GO:0003681',
#   'name': 'F:bent DNA binding',
#   'carried_by': ['P0ACF8']},
#  'GO:0046983': {'ID': 'GO:0046983',
#   'name': 'F:protein dimerization activity',
#   'carried_by': ['P0ACF8']},
#  'GO:0003723': {'ID': 'GO:0003723',
#   'name': 'F:RNA binding',
#   'carried_by': ['P0ACF8', 'P62399']},
#  'GO:0016458': {'ID': 'GO:0016458',
#   'name': 'P:gene silencing',
#   'carried_by': ['P0ACF8']},
#  'GO:1900232': {'ID': 'GO:1900232',
#   'name': 'P:negative regulation of single-species biofilm formation on inanimate substrate',
#   'carried_by': ['P0ACF8']},
#  'GO:0006417': {'ID': 'GO:0006417',
#   'name': 'P:regulation of translation',
#   'carried_by': ['P0ACF8']},
#  'GO:0022625': {'ID': 'GO:0022625',
#   'name': 'C:cytosolic large ribosomal subunit',
#   'carried_by': ['P62399']},
#  'GO:0008097': {'ID': 'GO:0008097',
#   'name': 'F:5S rRNA binding',
#   'carried_by': ['P62399']},
#  'GO:0000049': {'ID': 'GO:0000049',
#   'name': 'F:tRNA binding',
#   'carried_by': ['P62399']},
#  'GO:0000027': {'ID': 'GO:0000027',
#   'name': 'P:ribosomal large subunit assembly',
#   'carried_by': ['P62399']},
#  'GO:0009279': {'ID': 'GO:0009279',
#   'name': 'C:cell outer membrane',
#   'carried_by': ['P0A905',
#    'P76506',
#    'P13036',
#    'P10384',
#    'P06971',
#    'P0A910',
#    'P06996',
#    'P02931']},
#  'GO:0120010': {'ID': 'GO:0120010',
#   'name': 'P:intermembrane phospholipid transfer',
#   'carried_by': ['P76506']},
#  'GO:0016021': {'ID': 'GO:0016021',
#   'name': 'C:integral component of membrane',
#   'carried_by': ['P13036', 'P10384', 'P06971', 'P0A910', 'P02931']},
#  'GO:0015091': {'ID': 'GO:0015091',
#   'name': 'F:ferric iron transmembrane transporter activity',
#   'carried_by': ['P13036']},
#  'GO:0015344': {'ID': 'GO:0015344',
#   'name': 'F:siderophore uptake transmembrane transporter activity',
#   'carried_by': ['P13036', 'P06971']},
#  'GO:0038023': {'ID': 'GO:0038023',
#   'name': 'F:signaling receptor activity',
#   'carried_by': ['P13036', 'P06971']},
#  'GO:0055072': {'ID': 'GO:0055072',
#   'name': 'P:iron ion homeostasis',
#   'carried_by': ['P13036', 'P06971']},
#  'GO:0006826': {'ID': 'GO:0006826',
#   'name': 'P:iron ion transport',
#   'carried_by': ['P13036']},
#  'GO:0022834': {'ID': 'GO:0022834',
#   'name': 'F:ligand-gated channel activity',
#   'carried_by': ['P10384']},
#  'GO:0015483': {'ID': 'GO:0015483',
#   'name': 'F:long-chain fatty acid transporting porin activity',
#   'carried_by': ['P10384']},
#  'GO:0048037': {'ID': 'GO:0048037',
#   'name': 'F:cofactor binding',
#   'carried_by': ['P06971']},
#  'GO:0005506': {'ID': 'GO:0005506',
#   'name': 'F:iron ion binding',
#   'carried_by': ['P06971']},
#  'GO:0019904': {'ID': 'GO:0019904',
#   'name': 'F:protein domain specific binding',
#   'carried_by': ['P06971']},
#  'GO:0015643': {'ID': 'GO:0015643',
#   'name': 'F:toxic substance binding',
#   'carried_by': ['P06971']},
#  'GO:0046790': {'ID': 'GO:0046790',
#   'name': 'F:virion binding',
#   'carried_by': ['P06971']},
#  'GO:0019867': {'ID': 'GO:0019867',
#   'name': 'C:outer membrane',
#   'carried_by': ['P0A910']},
#  'GO:0046930': {'ID': 'GO:0046930',
#   'name': 'C:pore complex',
#   'carried_by': ['P0A910', 'P06996', 'P02931']},
#  'GO:0015288': {'ID': 'GO:0015288',
#   'name': 'F:porin activity',
#   'carried_by': ['P0A910', 'P06996', 'P02931']},
#  'GO:0006974': {'ID': 'GO:0006974',
#   'name': 'P:cellular response to DNA damage stimulus',
#   'carried_by': ['P0A910', 'P06996']},
#  'GO:0000746': {'ID': 'GO:0000746',
#   'name': 'P:conjugation',
#   'carried_by': ['P0A910']},
#  'GO:0009597': {'ID': 'GO:0009597',
#   'name': 'P:detection of virus',
#   'carried_by': ['P0A910']},
#  'GO:0034220': {'ID': 'GO:0034220',
#   'name': 'P:ion transmembrane transport',
#   'carried_by': ['P0A910', 'P06996', 'P02931']},
#  'GO:0006811': {'ID': 'GO:0006811',
#   'name': 'P:ion transport',
#   'carried_by': ['P0A910']},
#  'GO:0046718': {'ID': 'GO:0046718',
#   'name': 'P:viral entry into host cell',
#   'carried_by': ['P0A910']},
#  'GO:0045203': {'ID': 'GO:0045203',
#   'name': 'C:integral component of cell outer membrane',
#   'carried_by': ['P06996']},
#  'GO:0046872': {'ID': 'GO:0046872',
#   'name': 'F:metal ion binding',
#   'carried_by': ['P06996', 'P76344']},
#  'GO:0001618': {'ID': 'GO:0001618',
#   'name': 'F:virus receptor activity',
#   'carried_by': ['P06996']},
#  'GO:0015914': {'ID': 'GO:0015914',
#   'name': 'P:phospholipid transport',
#   'carried_by': ['P06996']},
#  'GO:0046813': {'ID': 'GO:0046813',
#   'name': 'P:receptor-mediated virion attachment to host cell',
#   'carried_by': ['P06996']},
#  'GO:0030288': {'ID': 'GO:0030288',
#   'name': 'C:outer membrane-bounded periplasmic space',
#   'carried_by': ['P76344']},
#  'GO:0046870': {'ID': 'GO:0046870',
#   'name': 'F:cadmium ion binding',
#   'carried_by': ['P76344']},
#  'GO:0008270': {'ID': 'GO:0008270',
#   'name': 'F:zinc ion binding',
#   'carried_by': ['P76344']},
#  'GO:0071276': {'ID': 'GO:0071276',
#   'name': 'P:cellular response to cadmium ion',
#   'carried_by': ['P76344']},
#  'GO:0070301': {'ID': 'GO:0070301',
#   'name': 'P:cellular response to hydrogen peroxide',
#   'carried_by': ['P76344']},
#  'GO:0034224': {'ID': 'GO:0034224',
#   'name': 'P:cellular response to zinc ion starvation',
#   'carried_by': ['P76344']},
#  'GO:0006882': {'ID': 'GO:0006882',
#   'name': 'P:cellular zinc ion homeostasis',
#   'carried_by': ['P76344']},
#  'GO:0034702': {'ID': 'GO:0034702',
#   'name': 'C:ion channel complex',
#   'carried_by': ['P02931']},
#  'GO:0042912': {'ID': 'GO:0042912',
#   'name': 'F:colicin transmembrane transporter activity',
#   'carried_by': ['P02931']},
#  'GO:0097718': {'ID': 'GO:0097718',
#   'name': 'F:disordered domain specific binding',
#   'carried_by': ['P02931']},
#  'GO:0005216': {'ID': 'GO:0005216',
#   'name': 'F:ion channel activity',
#   'carried_by': ['P02931']},
#  'GO:0015075': {'ID': 'GO:0015075',
#   'name': 'F:ion transmembrane transporter activity',
#   'carried_by': ['P02931']},
#  'GO:0008289': {'ID': 'GO:0008289',
#   'name': 'F:lipid binding',
#   'carried_by': ['P02931']},
#  'GO:0001530': {'ID': 'GO:0001530',
#   'name': 'F:lipopolysaccharide binding',
#   'carried_by': ['P02931']},
#  'GO:0047485': {'ID': 'GO:0047485',
#   'name': 'F:protein N-terminus binding',
#   'carried_by': ['P02931']},
#  'GO:0042910': {'ID': 'GO:0042910',
#   'name': 'F:xenobiotic transmembrane transporter activity',
#   'carried_by': ['P02931']},
#  'GO:0006855': {'ID': 'GO:0006855',
#   'name': 'P:drug transmembrane transport',
#   'carried_by': ['P02931']},
#  'GO:0070207': {'ID': 'GO:0070207',
#   'name': 'P:protein homotrimerization',
#   'carried_by': ['P02931']}}

# %%
import json
jsonGoFile = './data/EColiK12_GOcounts.json'

# K : current go term occurence in total proteome
# k : number of abundant proteins with current go term
# N : proteome size
# n : number of abundant proteins

go_ecoli_statistics = {}
with open(jsonGoFile, 'r') as f:
    go_ecoli_statistics = json.load(f)

N = go_ecoli_statistics['total_proteins']
n = len( df3["Accession"].to_list() )

from scipy.stats import hypergeom

results = []
for GO_term in abundant_proteins_go_terms.values():
    GO_id    = GO_term['ID']
    GO_count = len(GO_term['carried_by'])
    GO_name  =  GO_term['name']
    k = GO_count
    K = go_ecoli_statistics['go_terms'][GO_id]['count']
    #print(N,n,K,k)
    p_value = 1.0 - hypergeom.cdf(k - 1, N, K, n)
    results.append( (GO_id, GO_name, p_value, k) )

sorted(results, key=lambda x:x[2])
# Out:
# [('GO:0009279', 'C:cell outer membrane', 4.2278114342764184e-10, 8),
#  ('GO:0034220', 'P:ion transmembrane transport', 5.583727299862673e-06, 3),
#  ('GO:0046930', 'C:pore complex', 2.4271721519308898e-05, 3),
#  ('GO:0015288', 'F:porin activity', 2.850123274567018e-05, 3),
#  ('GO:0038023', 'F:signaling receptor activity', 0.00014059362830243227, 2),
#  ('GO:0015344',
#   'F:siderophore uptake transmembrane transporter activity',
#   0.0002614858350119542,
#   2),
#  ('GO:0055072', 'P:iron ion homeostasis', 0.0007218134333636383, 2),
#  ('GO:0001217',
#   'F:DNA-binding transcription repressor activity',
#   0.002716145165351791,
#   2),
#  ('GO:0045892',
#   'P:negative regulation of transcription, DNA-templated',
#   0.0027407407367546766,
#   3),
#  ('GO:0019395', 'P:fatty acid oxidation', 0.0031883397897817245, 1),
#  ('GO:0045723',
#   'P:positive regulation of fatty acid biosynthetic process',
#   0.0031883397897817245,
#   1),
#  ('GO:0019217',
#   'P:regulation of fatty acid metabolic process',
#   0.0031883397897817245,
#   1),
#  ('GO:0015091',
#   'F:ferric iron transmembrane transporter activity',
#   0.0031883397897817245,
#   1),
#  ('GO:0015483',
#   'F:long-chain fatty acid transporting porin activity',
#   0.0031883397897817245,
#   1),
#  ('GO:0009597', 'P:detection of virus', 0.0031883397897817245, 1),
#  ('GO:0046813',
#   'P:receptor-mediated virion attachment to host cell',
#   0.0031883397897817245,
#   1),
#  ('GO:0034702', 'C:ion channel complex', 0.0031883397897817245, 1),
#  ('GO:0015075',
#   'F:ion transmembrane transporter activity',
#   0.0031883397897817245,
#   1),
#  ('GO:0000062', 'F:fatty-acyl-CoA binding', 0.006367238011812826, 1),
#  ('GO:0016458', 'P:gene silencing', 0.006367238011812826, 1),
#  ('GO:0120010',
#   'P:intermembrane phospholipid transfer',
#   0.006367238011812826,
#   1),
#  ('GO:0022834', 'F:ligand-gated channel activity', 0.006367238011812826, 1),
#  ('GO:0046790', 'F:virion binding', 0.006367238011812826, 1),
#  ('GO:0001618', 'F:virus receptor activity', 0.006367238011812826, 1),
#  ('GO:0046870', 'F:cadmium ion binding', 0.006367238011812826, 1),
#  ('GO:0034224',
#   'P:cellular response to zinc ion starvation',
#   0.006367238011812826,
#   1),
#  ('GO:0006882', 'P:cellular zinc ion homeostasis', 0.006367238011812826, 1),
#  ('GO:0005216', 'F:ion channel activity', 0.006367238011812826, 1),
#  ('GO:0047485', 'F:protein N-terminus binding', 0.006367238011812826, 1),
#  ('GO:0032993', 'C:protein-DNA complex', 0.009402901411840858, 2),
#  ('GO:0003680', 'F:AT DNA binding', 0.009536720511419072, 1),
#  ('GO:0008097', 'F:5S rRNA binding', 0.009536720511419072, 1),
#  ('GO:0048037', 'F:cofactor binding', 0.009536720511419072, 1),
#  ('GO:0000746', 'P:conjugation', 0.009536720511419072, 1),
#  ('GO:0015914', 'P:phospholipid transport', 0.009536720511419072, 1),
#  ('GO:0071276', 'P:cellular response to cadmium ion', 0.009536720511419072, 1),
#  ('GO:0042912',
#   'F:colicin transmembrane transporter activity',
#   0.009536720511419072,
#   1),
#  ('GO:1900232',
#   'P:negative regulation of single-species biofilm formation on inanimate substrate',
#   0.012696813014716368,
#   1),
#  ('GO:0097718',
#   'F:disordered domain specific binding',
#   0.012696813014716368,
#   1),
#  ('GO:0001530', 'F:lipopolysaccharide binding', 0.012696813014716368, 1),
#  ('GO:0003735',
#   'F:structural constituent of ribosome',
#   0.014093562278425953,
#   2),
#  ('GO:0003681', 'F:bent DNA binding', 0.01584754121197207, 1),
#  ('GO:0015643', 'F:toxic substance binding', 0.01584754121197207, 1),
#  ('GO:0006412', 'P:translation', 0.017509986358347218, 2),
#  ('GO:0045893',
#   'P:positive regulation of transcription, DNA-templated',
#   0.018545263855781702,
#   2),
#  ('GO:0048027', "F:mRNA 5'-UTR binding", 0.01898893073231367, 1),
#  ('GO:0006826', 'P:iron ion transport', 0.01898893073231367, 1),
#  ('GO:0070181',
#   'F:small ribosomal subunit rRNA binding',
#   0.02212100712247811,
#   1),
#  ('GO:0070207', 'P:protein homotrimerization', 0.02212100712247811, 1),
#  ('GO:0008289', 'F:lipid binding', 0.02524379587206882, 1),
#  ('GO:0003723', 'F:RNA binding', 0.025886815498500693, 2),
#  ('GO:0000976',
#   'F:transcription regulatory region sequence-specific DNA binding',
#   0.027726105733795525,
#   2),
#  ('GO:0006855', 'P:drug transmembrane transport', 0.03146161212249188, 1),
#  ('GO:0009295', 'C:nucleoid', 0.03455669030313968, 1),
#  ('GO:0019904', 'F:protein domain specific binding', 0.03455669030313968, 1),
#  ('GO:0070301',
#   'P:cellular response to hydrogen peroxide',
#   0.03455669030313968,
#   1),
#  ('GO:0042802', 'F:identical protein binding', 0.03493008596109215, 4),
#  ('GO:0046718', 'P:viral entry into host cell', 0.04071931287356845, 1),
#  ('GO:0045203',
#   'C:integral component of cell outer membrane',
#   0.04071931287356845,
#   1),
#  ('GO:0046983', 'F:protein dimerization activity', 0.043786907578658774, 1),
#  ('GO:0019867', 'C:outer membrane', 0.043786907578658774, 1),
#  ('GO:0016021', 'C:integral component of membrane', 0.04709547138395531, 5),
#  ('GO:0006417', 'P:regulation of translation', 0.049894789055546895, 1),
#  ('GO:0006811', 'P:ion transport', 0.07396585285455337, 1),
#  ('GO:0022627', 'C:cytosolic small ribosomal subunit', 0.07693459066655739, 1),
#  ('GO:0000156',
#   'F:phosphorelay response regulator activity',
#   0.07989448890767115,
#   1),
#  ('GO:0000027', 'P:ribosomal large subunit assembly', 0.08284557187932617, 1),
#  ('GO:0042910',
#   'F:xenobiotic transmembrane transporter activity',
#   0.08284557187932617,
#   1),
#  ('GO:0005829', 'C:cytosol', 0.08474830672934075, 6),
#  ('GO:0022625', 'C:cytosolic large ribosomal subunit', 0.09746960385574532, 1),
#  ('GO:0001216',
#   'F:DNA-binding transcription activator activity',
#   0.10325835341741185,
#   1),
#  ('GO:0016020', 'C:membrane', 0.12910152779854278, 2),
#  ('GO:0006974',
#   'P:cellular response to DNA damage stimulus',
#   0.12910152779854278,
#   2),
#  ('GO:0003700',
#   'F:DNA-binding transcription factor activity',
#   0.13017816523785852,
#   2),
#  ('GO:0000160',
#   'P:phosphorelay signal transduction system',
#   0.13168849848330355,
#   1),
#  ('GO:0000049', 'F:tRNA binding', 0.1344849928567351, 1),
#  ('GO:0005506', 'F:iron ion binding', 0.15108909995111974, 1),
#  ('GO:0046872', 'F:metal ion binding', 0.2986525101418964, 2),
#  ('GO:0003677', 'F:DNA binding', 0.32915555333371493, 2),
#  ('GO:0008270', 'F:zinc ion binding', 0.38979423657384626, 1),
#  ('GO:0006355',
#   'P:regulation of transcription, DNA-templated',
#   0.3978184376800423,
#   1),
#  ('GO:0030288',
#   'C:outer membrane-bounded periplasmic space',
#   0.43461284951540036,
#   1)]
